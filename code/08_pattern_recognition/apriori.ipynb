# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('../01_preprocess/files_ps/ycsb_c_ps.csv')

# Display the DataFrame
df
# Out:
#       const_basicHintCount  const_enableBasicHead  const_enableDense  \
# 0                       16                      1                  0
# 1                        0                      0                  0
# 2                       16                      1                  0
# 3                       16                      1                  0
# 4                       16                      1                  1
# ...                    ...                    ...                ...
# 2866                     0                      0                  0
# 2867                    16                      1                  0
# 2868                     0                      0                  0
# 2869                     0                      0                  0
# 2870                    16                      1                  0
#
#       const_enableDense2  const_enableDensifySplit  const_enableHash  \
# ...

# %%
df['percentile bracket'] = pd.qcut(df['time'], q=10, labels=False, duplicates='drop') + 1
df.drop([ 'time', 'rand_seed'], axis=1, inplace=True)

# %%
df = pd.get_dummies(df, columns=df.columns)
df
# Out:
#       const_basicHintCount_0  const_basicHintCount_16  \
# 0                      False                     True
# 1                       True                    False
# 2                      False                     True
# 3                      False                     True
# 4                      False                     True
# ...                      ...                      ...
# 2866                    True                    False
# 2867                   False                     True
# 2868                    True                    False
# 2869                    True                    False
# 2870                   False                     True
#
#       const_enableBasicHead_0  const_enableBasicHead_1  const_enableDense_0  \
# 0                       False                     True                 True
# 1                        True                    False                 True
# 2                       False                     True                 True
# ...

# %%
from mlxtend.frequent_patterns import apriori

apriori(df, min_support=0.3, use_colnames=True, low_memory=True)
