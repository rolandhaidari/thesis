# %%
from interpret import set_visualize_provider
from interpret.provider import InlineProvider
set_visualize_provider(InlineProvider())

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('../01_preprocess/preprocessed.csv')
# Calculate the percentile brackets
df['percentile bracket'] = pd.qcut(df['time'], q=10, labels=False, duplicates='drop') + 1

df.drop(['cycle', 'instr', 'LLC_miss','CPU','L1_miss', 'br_miss', 'scale', 'counted_final_key_count', 'GHz', 'time', 'task', 'IPC'], axis=1, inplace=True)
df.drop(['nodeCount_Leaf', 'nodeCount_Inner', 'nodeCount_Dense', 'nodeCount_Hash', 'nodeCount_Head4', 'nodeCount_Head8', 'nodeCount_Dense2'], axis=1, inplace=True)

df.head()
# Out:
#   config_name  const_basicHintCount  const_enableBasicHead  const_enableDense  \
# 0        hash                    16                      1                  0
# 1        hash                    16                      1                  0
# 2      dense3                    16                      1                  1
# 3      dense3                    16                      1                  1
# 4       hints                    16                      1                  0
#
#    const_enableDense2  const_enableDensifySplit  const_enableHash  \
# 0                   0                         0                 1
# 1                   0                         0                 1
# 2                   0                         1                 0
# 3                   0                         1                 0
# 4                   0                         0                 0
#
#    const_enableHashAdapt  const_enableHeadNode  const_enablePrefix  ...  \
# 0                      0                     0                   1  ...
# 1                      0                     0                   1  ...
# 2                      0                     0                   1  ...
# 3                      0                     0                   1  ...
# 4                      0                     0                   1  ...
#
#    data_name  data_size  data_sorted   density           op  payload_size  \
# 0  data/urls  5798920.0          0.0  0.531252  ycsb_c_init           8.0
# 1  data/urls  5798920.0          0.0  0.531252       ycsb_c           8.0
# 2  data/urls  3175985.0          0.0  0.641406  ycsb_c_init           8.0
# 3  data/urls  3175985.0          0.0  0.641406       ycsb_c           8.0
# 4  data/urls  4933290.0          0.0  0.876636  ycsb_e_init           8.0
#
#       rand_seed  ycsb_range_len ycsb_zipf  percentile bracket
# 0  1.701944e+09           100.0  1.133614                   3
# 1  1.701944e+09           100.0  1.133614                   1
# 2  1.701944e+09           100.0  0.316120                   6
# 3  1.701944e+09           100.0  0.316120                   7
# 4  1.701944e+09           100.0  0.666485                   7
#
# [5 rows x 28 columns]

# %%
# Identify non-numeric columns
non_numeric_columns = df.select_dtypes(['object']).columns

print("Number of columns:", df.shape[1])

# Apply one-hot encoding to non-numeric columns
df = pd.get_dummies(df, columns=non_numeric_columns)

print("Number of columns after one-hot:", df.shape[1])
# Out:
# Number of columns: 28
# Number of columns after one-hot: 33

# %%
df = df[df['op_ycsb_c'] == True]
df
# Out:
#        const_basicHintCount  const_enableBasicHead  const_enableDense  \
# 1                        16                      1                  0
# 3                        16                      1                  1
# 7                        16                      1                  0
# 9                        16                      1                  1
# 11                       16                      1                  0
# ...                     ...                    ...                ...
# 64431                    16                      1                  0
# 64433                    16                      1                  1
# 64435                    16                      1                  0
# 64437                    16                      1                  0
# 64439                    16                      1                  0
#
#        const_enableDense2  const_enableDensifySplit  const_enableHash  \
# 1                       0                         0                 1
# 3                       0                         1                 0
# 7                       0                         0                 0
# 9                       0                         1                 0
# 11                      0                         0                 0
# ...                   ...                       ...               ...
# 64431                   0                         0                 0
# 64433                   0                         1                 0
# 64435                   0                         0                 0
# 64437                   0                         0                 1
# 64439                   0                         0                 0
#
#        const_enableHashAdapt  const_enableHeadNode  const_enablePrefix  \
# 1                          0                     0                   1
# 3                          0                     0                   1
# 7                          0                     0                   1
# 9                          0                     0                   1
# 11                         0                     0                   1
# ...                      ...                   ...                 ...
# 64431                      0                     0                   1
# 64433                      0                     0                   1
# 64435                      0                     0                   1
# 64437                      0                     0                   1
# 64439                      0                     0                   1
#
#        const_hashSimdWidth  ...  ycsb_zipf  percentile bracket  \
# 1                       32  ...   1.133614                   1
# 3                       32  ...   0.316120                   7
# 7                       32  ...   0.484175                   9
# 9                       32  ...   0.444470                   7
# 11                      32  ...   0.163519                   9
# ...                    ...  ...        ...                 ...
# 64431                   32  ...   1.423165                   1
# 64433                   32  ...   1.284978                   1
# 64435                   32  ...   1.488763                   1
# 64437                   32  ...   1.040459                   2
# 64439                   32  ...   0.004875                   9
#
#        config_name_dense3  config_name_hash  config_name_hints  \
# 1                   False              True              False
# 3                    True             False              False
# 7                   False             False               True
# 9                    True             False              False
# 11                  False             False               True
# ...                   ...               ...                ...
# 64431               False             False               True
# 64433                True             False              False
# 64435               False             False               True
# 64437               False              True              False
# 64439               False             False               True
#
#        data_name_data/urls  op_ycsb_c  op_ycsb_c_init  op_ycsb_e  \
# 1                     True       True           False      False
# 3                     True       True           False      False
# 7                     True       True           False      False
# 9                     True       True           False      False
# 11                    True       True           False      False
# ...                    ...        ...             ...        ...
# 64431                 True       True           False      False
# 64433                 True       True           False      False
# 64435                 True       True           False      False
# 64437                 True       True           False      False
# 64439                 True       True           False      False
#
#        op_ycsb_e_init
# 1               False
# 3               False
# 7               False
# 9               False
# 11              False
# ...               ...
# 64431           False
# 64433           False
# 64435           False
# 64437           False
# 64439           False
#
# [22644 rows x 33 columns]

# %%
boolean_columns = df.select_dtypes(include=bool).columns
df[boolean_columns] = df[boolean_columns].applymap(lambda x: 1 if x else 0)
df
df
# Out:
# /tmp/ipykernel_15661/1084280440.py:2: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#        const_basicHintCount  const_enableBasicHead  const_enableDense  \
# 1                        16                      1                  0
# 3                        16                      1                  1
# 7                        16                      1                  0
# 9                        16                      1                  1
# 11                       16                      1                  0
# ...                     ...                    ...                ...
# 64431                    16                      1                  0
# 64433                    16                      1                  1
# 64435                    16                      1                  0
# 64437                    16                      1                  0
# 64439                    16                      1                  0
#
#        const_enableDense2  const_enableDensifySplit  const_enableHash  \
# 1                       0                         0                 1
# 3                       0                         1                 0
# 7                       0                         0                 0
# 9                       0                         1                 0
# 11                      0                         0                 0
# ...                   ...                       ...               ...
# 64431                   0                         0                 0
# 64433                   0                         1                 0
# 64435                   0                         0                 0
# 64437                   0                         0                 1
# 64439                   0                         0                 0
#
#        const_enableHashAdapt  const_enableHeadNode  const_enablePrefix  \
# 1                          0                     0                   1
# 3                          0                     0                   1
# 7                          0                     0                   1
# 9                          0                     0                   1
# 11                         0                     0                   1
# ...                      ...                   ...                 ...
# 64431                      0                     0                   1
# 64433                      0                     0                   1
# 64435                      0                     0                   1
# 64437                      0                     0                   1
# 64439                      0                     0                   1
#
#        const_hashSimdWidth  ...  ycsb_zipf  percentile bracket  \
# 1                       32  ...   1.133614                   1
# 3                       32  ...   0.316120                   7
# 7                       32  ...   0.484175                   9
# 9                       32  ...   0.444470                   7
# 11                      32  ...   0.163519                   9
# ...                    ...  ...        ...                 ...
# 64431                   32  ...   1.423165                   1
# 64433                   32  ...   1.284978                   1
# 64435                   32  ...   1.488763                   1
# 64437                   32  ...   1.040459                   2
# 64439                   32  ...   0.004875                   9
#
#        config_name_dense3  config_name_hash  config_name_hints  \
# 1                       0                 1                  0
# 3                       1                 0                  0
# 7                       0                 0                  1
# 9                       1                 0                  0
# 11                      0                 0                  1
# ...                   ...               ...                ...
# 64431                   0                 0                  1
# 64433                   1                 0                  0
# 64435                   0                 0                  1
# 64437                   0                 1                  0
# 64439                   0                 0                  1
#
#        data_name_data/urls  op_ycsb_c  op_ycsb_c_init  op_ycsb_e  \
# 1                        1          1               0          0
# 3                        1          1               0          0
# 7                        1          1               0          0
# 9                        1          1               0          0
# 11                       1          1               0          0
# ...                    ...        ...             ...        ...
# 64431                    1          1               0          0
# 64433                    1          1               0          0
# 64435                    1          1               0          0
# 64437                    1          1               0          0
# 64439                    1          1               0          0
#
#        op_ycsb_e_init
# 1                   0
# 3                   0
# 7                   0
# 9                   0
# 11                  0
# ...               ...
# 64431               0
# 64433               0
# 64435               0
# 64437               0
# 64439               0
#
# [22644 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('percentile bracket', axis=1), df['percentile bracket'], test_size=0.2, random_state=42)

# Create a decision tree classifier
clf = DecisionTreeClassifier(random_state=42)

# Fit the classifier to the training data
clf.fit(X_train, y_train)

# Predict the percentile brackets for the test data
y_pred = clf.predict(X_test)

# Evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8116582026937513

# %%
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

from interpret import show
from interpret.blackbox import LimeTabular
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('percentile bracket', axis=1), df['percentile bracket'], test_size=0.2, random_state=42)

# Create a decision tree classifier
clf = DecisionTreeClassifier(random_state=42)
blackbox_model = Pipeline([('clf', clf)])
blackbox_model.fit(X_train, y_train)
lime = LimeTabular(blackbox_model, X_train)

show(lime.explain_local(X_test[:5], y_test[:5]), 0)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 15
#      12 blackbox_model.fit(X_train, y_train)
#      13 lime = LimeTabular(blackbox_model, X_train)
# ---> 15 show(lime.explain_local(X_test[:5], y_test[:5]), 0)
#
# File ~/.cache/pypoetry/virtualenvs/code-RswzgKQQ-py3.11/lib/python3.11/site-packages/interpret/blackbox/_lime.py:91, in LimeTabular.explain_local(self, X, y, name, **kwargs)
#      89 predict_fn, n_classes, classes = determine_classes(self.model, X, n_samples)
#      90 if 3 <= n_classes:
# ---> 91     raise Exception("multiclass LIME not supported")
#      92 predict_fn = unify_predict_fn(predict_fn, X, 1 if n_classes == 2 else -1)
#      94 X, _, _ = unify_data(
#      95     X, n_samples, self.feature_names_in_, self.feature_types_in_, False, 0
#      96 )
#
# Exception: multiclass LIME not supported
